# %% [markdown]
# # 1. What is Agent-Based Modeling and Why Should You Use It?

# %% [markdown]
# ## 1.1 An Initial Exploration

# %% [markdown]
# References:
# Wilensky, U. (1998). NetLogo Flocking model. http://ccl.northwestern.edu/netlogo/models/Flocking. Center for Connected Learning and Computer-Based Modeling, Northwestern University, Evanston, IL.
#
# - instructor: William Rand
# - instructor: Anamaria Berea
# - teaching assistant: Kasia Samson
#
# ### Information on versions of NetLogo used in this course
# - 6.3.0 (latest stable release as of June 2024)
# - https://www.netlogo.org/
#
# ### Three Rules
# Reference: Craig Raynolds, The Boids Model: http://www.red3d.com/cwr/boids/
#
# #### The Boids Model - Craig W. Reynolds, SIGGRAPH, 1987
# - How do birds flock?
#   - neighborhood: flock mates
#
# ##### Rules:
#   - align rule
#   - cohere rule
#   - separate rule
#
# ### Uri Wilenksy, NetLogo author
# https://s3.amazonaws.com/complexityexplorer/ABMwithNetLogo/ABM-MOOC-slides-distribute.pdf
#
# References:
# - Wilensky, Uri, and S. Papert. "Restructurations: Reformulations of knowledge disciplines through new representational forms." Constructionism (2010).
# - Wilensky, U. (1997). NetLogo Fire model. http://ccl.northwestern.edu/netlogo/models/Fire. Center for Connected Learning and Computer-Based Modeling, Northwestern University, Evanston, IL.

# %% [markdown]
# ## 1.2 Course Overview

# %% [markdown]
# ## 1.3 What is Agent-Based Modeling?

# %% [markdown]
# ## 1.4 Introductory Models

# %% [markdown]
# ## 1.5 Complex Models

# %% [markdown]
# ## 1.6 Complexity, Emergence, and Feedbacks

# %% [markdown]
# ## 1.7 Why use ABM?

# %% [markdown]
# ## 1.8 When Should You Use ABM?

# %% [markdown]
# ## 1.9 Comparing ABM to Other Methods

# %% [markdown]
# ## 1.10 What Good Is an Agent-Based Model?

# %% [markdown]
# ## 1.11 Review
