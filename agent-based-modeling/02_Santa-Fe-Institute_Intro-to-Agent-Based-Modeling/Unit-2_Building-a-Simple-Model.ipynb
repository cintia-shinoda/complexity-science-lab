# %% [markdown]
# # 2. Building a Simple Model

# %% [markdown]
# ## 2.1 Intro to NetLogo

# %% [markdown]
# ## 2.2 Turtles, Patches, and Links

# %% [markdown]
# ## 2.3 Code and Properties

# %% [markdown]
# ## 2.4 Heroes and Cowards

# %% [markdown]
# ## 2.5 Extending the Heroes and Cowards Model

# %% [markdown]
# ## 2.6 Review
